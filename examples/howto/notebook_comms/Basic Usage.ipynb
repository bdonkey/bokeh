subtype":"Figure","type":"Plot"},"ticker":{"id":"5ea52263-f043-4282-bf89-8257b0a19575","type":"BasicTicker"}},"id":"3fe4d802-6abb-4857-9add-a8a56c464883","type":"LinearAxis"},{"attributes":{},"id":"5ea52263-f043-4282-bf89-8257b0a19575","type":"BasicTicker"},{"attributes":{"data_source":{"id":"ce520a3e-cec5-4828-a15b-a5574dbe681d","type":"ColumnDataSource"},"glyph":{"id":"84056514-74bb-4d68-950c-9dad92bd57d5","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"247c7404-605e-4905-8c67-b3a3b5a7fcb7","type":"Circle"},"selection_glyph":null},"id":"32e26e41-0684-41e9-b613-2b72c603a9d7","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"63f86060-38a1-42c0-9048-2bcacced684a","subtype":"Figure","type":"Plot"},"ticker":{"id":"5ea52263-f043-4282-bf89-8257b0a19575","type":"BasicTicker"}},"id":"221087b1-819b-4d3f-93b2-52daf5146b62","type":"Grid"},{"attributes":{"formatter":{"id":"195398fd-ef9d-4685-8e31-a4ed5ec17226","type":"BasicTickFormatter"},"plot":{"id":"63f86060-38a1-42c0-9048-2bcacced684a","subty ...

# %%
# the comms handle repr show what cell it can be used to update
t
# Out:
# <p><code>&lt;Bokeh Notebook handle for <strong>In[6]</strong>&gt;</code></p>

# %%
# this will update the left plot circle color with an explicit handle
r1.glyph.fill_color = "white"
push_notebook(handle=t)

# %%
# and this will update the right plot circle color because it was in the last shown cell
r2.glyph.fill_color = "pink"
push_notebook()

# %%
p3 = figure(**opts)
r3 = p3.circle([1,2,3], [4,5,6], size=20)

# get a handle to update the shown cell with
t2 = show(p3, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="7ef38ac5-02bb-478b-a386-a79678e45e78"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("7ef38ac5-02bb-478b-a386-a79678e45e78");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("5b39de9f-99e6-4252-bb59-0e58d135ebe9", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7ef38ac5-02bb-478b-a386-a79678e45e78");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7ef38ac5-02bb-478b-a386-a79678e45e78' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"14286abc-fff0-4753-b9a7-1cb2dfeff685":{"roots":{"references":[{"attributes":{"plot":{"id":"578e3350-6ae0-45c3-9213-44d32441ca63","subtype":"Figure","type":"Plot"}},"id":"09c2eb2a-82f2-4ba7-adf2-18129c5c2bef","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"578e3350-6ae0-45c3-9213-44d32441ca63","subtype":"Figure","type":"Plot"}},"id":"89c8980a-f1cd-4e12-a920-fa6e0b370402","type":"SaveTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"b006261b-fcc6-4c27-962f-a682c14b6684","type":"BoxAnnotation"},{"attributes":{"overlay":{"id":"b006261b-fcc6-4c27-962f-a682c14b6684","type":"BoxAnnotation"},"plot":{"id":"578e3350-6ae0-45c3-9213-44d32441ca63","subtype":"Figure","type":"Plot"}},"id":"f0fb54df-bd8c-4213-b8b3-95f1471f3693","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"578e3350-6ae0-45c3-9213-44d32441ca63","subtype":"Figure","type":"Plot"}},"id":"e27cc951-d537-4891-bc2f-fc34a6d9417e","type":"ResetTool"},{"attributes":{"plot":{"id":"578e3350-6ae0-45c3-9213-44d32441ca63","subtype":"Figure","type":"Plot"}},"id":"e47370a8-2776-429d-b656-4e61c497d3bb","type":"PanTool"},{"attributes":{"plot":{"id":"578e3350-6ae0-45c3-9213-44d32441ca63","subtype":"Figure","type":"Plot"}},"id":"833ed420-a36f-45a0-8ec7-3b7461c88fcc","type":"HelpTool"},{"attributes":{},"id":"7983a83d-baee-4012-b8c4-a2291cfb756e","type":"BasicTickFormatter"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"e47370a8-2776-429d-b656-4e61c497d3bb","type":"PanTool"},{"id":"09c2eb2a-82f2-4ba7-adf2-18129c5c2bef","type":"WheelZoomTool"},{"id":"f0fb54df-bd8c-4213-b8b3-95f1471f3693","type":"BoxZoomTool"},{"id":"89c8980a-f1cd-4e12-a920-fa6e0b370402","type":"SaveTool"},{"id":"e27cc951-d537-4891-bc2f-fc34a6d9417e","type":"ResetTool"},{"id":"833ed420-a36f-45a0-8ec7-3b7461c88fcc","type":"HelpTool"}]},"id":"d3db274b-a51c-404e-a8b4-be091613b2d1","type":"Toolbar"},{"attributes":{"below":[{"id":"6c40fdc3-e1e9-4d65-875c-7fa0ecd04687","type":"LinearAxis"}],"left":[{"id":"cd2928bf-3733-46ac-a8f5-0b63d47fafae","type":"LinearAxis"}],"min_border":0,"plot_height":250,"plot_width":250,"renderers":[{"id":"6c40fdc3-e1e9-4d65-875c-7fa0ecd04687","type":"LinearAxis"},{"id":"615269f5-637d-4f7a-9a41-0314e40b225a","type":"Grid"},{"id":"cd2928bf-3733-46ac-a8f5-0b63d47fafae","type":"LinearAxis"},{"id":"b48272a2-87b8-47b9-8a06-52edffb846cc","type":"Grid"},{"id":"b006261b-fcc6-4c27-962f-a682c14b6684","type":"BoxAnnotation"},{"id":"8e7b07fa-095e-43f7-84a7-b4bd8ed73332","type":"GlyphRenderer"}],"title":{"id":"5839c44a-831e-4a55-8180-22e22028f44e","type":"Title"},"tool_events":{"id":"115ec2dd-de17-4c8f-b657-420dff3dedc0","type":"ToolEvents"},"toolbar":{"id":"d3db274b-a51c-404e-a8b4-be091613b2d1","type":"Toolbar"},"x_range":{"id":"26e497fb-e031-4efb-b519-269b4cdd2c40","type":"DataRange1d"},"y_range":{"id":"9457f298-75cd-4c16-9af9-51ae4ebec36a","type":"DataRange1d"}},"id":"578e3350-6ae0-45c3-9213-44d32441ca63","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1,2,3],"y":[4,5,6]}},"id":"7d05ac66-b576-4cfc-800f-604dbcb553cb","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"7d05ac66-b576-4cfc-800f-604dbcb553cb","type":"ColumnDataSource"},"glyph":{"id":"0dc61da6-168f-4854-b10e-92ae9e0c989a","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"c787b4e9-9afb-44bf-a560-0007daaf953d","type":"Circle"},"selection_glyph":null},"id":"8e7b07fa-095e-43f7-84a7-b4bd8ed73332","type":"GlyphRenderer"},{"attributes":{},"id":"115ec2dd-de17-4c8f-b657-420dff3dedc0","type":"ToolEvents"},{"attributes":{"formatter":{"id":"7983a83d-baee-4012-b8c4-a2291cfb756e","type":"BasicTickFormatter"},"plot": ...

# %%
# show which cell t2 handles
t2
# Out:
# <p><code>&lt;Bokeh Notebook handle for <strong>In[10]</strong>&gt;</code></p>

# %%
# this updates the immediately previous cell with an explicit handle
r3.glyph.fill_color = "orange"
push_notebook(handle=t2)

# %%
# this updates the left plot at the top with an explicit handle
r1.glyph.fill_color = "orange"
push_notebook(handle=t)

# %%
# get a handle to update the shown cell with
t3 = show(p2, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="4eafbf2c-5241-45a0-963f-c9e7acf4471a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("4eafbf2c-5241-45a0-963f-c9e7acf4471a");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("000388d2-eb43-42b4-9017-babfdaaae488", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4eafbf2c-5241-45a0-963f-c9e7acf4471a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4eafbf2c-5241-45a0-963f-c9e7acf4471a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"117063c4-7c93-48de-8d12-b151d4aec4a5":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1,2,3],"y":[4,5,6]}},"id":"ce520a3e-cec5-4828-a15b-a5574dbe681d","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"28fbb915-8b09-4d26-9eae-50c4a57b0081","type":"DataRange1d"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"349d77ac-11a2-4507-83a5-e36fb9e367c0","type":"PanTool"},{"id":"b21e1eb0-bd54-4b6d-8cb9-9f24965ec393","type":"WheelZoomTool"},{"id":"5f61e968-7ff1-431b-a70d-e0876547d432","type":"BoxZoomTool"},{"id":"1a3a89f9-9990-402a-ba7c-3b47412e3f9b","type":"SaveTool"},{"id":"a0364112-467c-40f2-89f5-ca6a7fdafddf","type":"ResetTool"},{"id":"33594124-92e5-4806-b7bd-d478f2f3a854","type":"HelpTool"}]},"id":"a8d4af23-fd5f-40ee-beb8-7e9ae51d7f09","type":"Toolbar"},{"attributes":{"fill_color":{"value":"pink"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":20},"x":{"field":"x"},"y":{"field":"y"}},"id":"84056514-74bb-4d68-950c-9dad92bd57d5","type":"Circle"},{"attributes":{"callback":null},"id":"702f3297-40a1-4582-8682-6ea0cd404afe","type":"DataRange1d"},{"attributes":{"formatter":{"id":"6dfb1bce-367f-4bd2-9b12-5555f4abd829","type":"BasicTickFormatter"},"plot":{"id":"ef61fe14-cb66-46e2-bfbd-f5ac45a83e6c","subtype":"Figure","type":"Plot"},"ticker":{"id":"9942ba52-8e0d-4564-b535-79c4e8c8a940","type":"BasicTicker"}},"id":"105d7c36-5849-42cd-b369-ff3198b9248d","type":"LinearAxis"},{"attributes":{},"id":"9942ba52-8e0d-4564-b535-79c4e8c8a940","type":"BasicTicker"},{"attributes":{"plot":{"id":"ef61fe14-cb66-46e2-bfbd-f5ac45a83e6c","subtype":"Figure","type":"Plot"},"ticker":{"id":"9942ba52-8e0d-4564-b535-79c4e8c8a940","type":"BasicTicker"}},"id":"68133289-3702-4056-ac69-db02ceed00d7","type":"Grid"},{"attributes":{"formatter":{"id":"e7c52d5e-7163-4768-bd02-49cd48470e87","type":"BasicTickFormatter"},"plot":{"id":"ef61fe14-cb66-46e2-bfbd-f5ac45a83e6c","subtype":"Figure","type":"Plot"},"ticker":{"id":"0ee6294c-6665-4aac-b018-c3771f1639b8","type":"BasicTicker"}},"id":"681c925d-e7ef-4f17-b4d6-bc607a8c9283","type":"LinearAxis"},{"attributes":{},"id":"0ee6294c-6665-4aac-b018-c3771f1639b8","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"ef61fe14-cb66-46e2-bfbd-f5ac45a83e6c","subtype":"Figure","type":"Plot"},"ticker":{"id":"0ee6294c-6665-4aac-b018-c3771f1639b8","type":"BasicTicker"}},"id":"f949edf9-ae1e-4501-b985-a0ec433afd7b","type":"Grid"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":20},"x":{"field":"x"},"y":{"field":"y"}},"id":"247c7404-605e-4905-8c67-b3a3b5a7fcb7","type":"Circle"},{"attributes":{},"id":"e7c52d5e-7163-4768-bd02-49cd48470e87","type":"BasicTickFormatter"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"ed497aea-4850-473e-b12a-b93ade158dc6","type":"BoxAnnotation"},{"attributes":{},"id":"4ab79a34-73f3-4d71-8b98-6264686fe269","type":"ToolEvents"},{"attributes":{"plot":{"id":"ef61fe14-cb66-46e2-bfbd-f5ac45a83e6c","subtype":"Figure","type":"Plot"}},"id":"349d77ac-11a2-4507-83a5-e36fb9e367c0","type":"PanTool"},{"attributes":{"plot":null,"text":""},"id":"63d5a8c6-c4c0-4a8f-ba4d-3b6ac9fa1863","type":"Title"},{"attributes":{"plot":{"id":"ef61fe14-cb66-46e2-bfbd-f5ac45a83e6c","subtype":"Figure","type":"Plot"}},"id":"b21e1eb0-bd54-4b6d-8cb9-9f24965ec393","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"ed497aea-4850-473e-b12a-b93ade158dc6","type":"BoxAnnotation"},"plot":{"id":"ef61fe14-cb66-46e2-bfbd-f5ac45a83e6c","subtype":"Figure","type":"Plot"}},"id":"5f61e968-7ff1-431b-a70d-e0876547d4 ...

# %%
# this will update the immediately previous plot circle color because it was in the last shown cell
r2.glyph.fill_color = "red"
push_notebook()

# %%
# this will update the immediately previous plot circle color with an explicit handle
r2.glyph.fill_color = "blue"
push_notebook(handle=t3)
